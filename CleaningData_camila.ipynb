# %%
import pandas as pd
import numpy as np
from pathlib import Path
import re
import nltk
nltk.download(['punkt','stopwords','wordnet'])
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to /home/cmejia3/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/cmejia3/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/cmejia3/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
stopWords = stopwords.words('english')

# %%
listoStopWords = ['www','https','html']

# %%
stopWords.extend(listoStopWords)

# %%
'www' in stopWords
# Out:
# True

# %%
def clean_files(texto,stopWords):
    texto = re.sub('[^A-Za-z0-9]+',' ',texto)
    
    #Pasar todo a minisculas
    texto = texto.lower()
    
    #Tokenizar
    tokens = texto.split()

    #Solo las palabras que tengas mas de un caracter, alpha y no stopword
    tokens = [w for w in tokens if (len(w)>1)&(w.isalpha() or len(w)==4)&(w not in stopWords)]
    
    #Stemmer
    ps = PorterStemmer() 
    tokens = [ps.stem(w) for w in tokens]
    
    word_net_lemmatizar = WordNetLemmatizer()

    tokens = [word_net_lemmatizar.lemmatize(w, pos = "v") for w in tokens]
    to_return = ' '.join(tokens)
    set_words = set(tokens)
    freq = nltk.FreqDist(tokens)
    return to_return,set_words,freq

# %%
base_path = base_path = Path("~").expanduser().resolve()
input_file_path  = base_path / 'datasets/papers-txt'

# %%
vocabulary = set()
results_text = []
results_frecuency = []

# %%
for f in input_file_path.glob('*.txt'):
    input_file = open(f, "r", encoding = 'utf-8')
    texto = input_file.read()
    text_cleanned,set_words,freq = clean_files(texto,stopWords)
    vocabulary = vocabulary.union(set_words)
    results_text.append(text_cleanned)
    results_frecuency.append(freq)

# %%
texto
# Out:
# 'Towards Power Efficient MAC Protocol for In-Body\nand On-Body Sensor Networks\nSana Ullah, Xizhi An, and Kyung Sup Kwak\nGraduate School of Telecommunication Engineering\n253 Yonghyun-Dong, Nam-Gu, 402-751, Inha University Incheon South Korea\nsanajcs@hotmail.com, anxizhi@hotmail.com, kskwak@inha.ac.kr\n\nAbstract. This paper presents an empirical discussion on the design and implementation of a power-efficient Medium Access Control (MAC) protocol for\nin-body and on-body sensor networks. We analyze the performance of a beacon-enabled IEEE 802.15.4, PB-TDMA, and S-MAC protocols for on-body\nsensor networks. We further present a Traffic Based Wakeup Mechanism that\nutilizes the traffic patterns of the BAN Nodes (BNs) to accommodate the entire\nBSN traffic. To enable a logical connection between different BNs working on\ndifferent frequency bands, a method called Bridging function is proposed. The\nBridging function integrates all BNs working on different bands into a complete\nBSN.\nKeywords: BSN, WBAN, MAC, Traffic, Based, Mechanisms, Bridging, Inbody, On-body, Sensor Networks.\n\n1 Introduction\nThe remote monitoring of body status and the surrounding environment are becoming more important for sporting activities, the safety of members of the emergency\nservices, members of the military and health care. The levels of fitness required for\nthe very competitive international sporting events require athletes to be at the very\npinnacle of fitness with every muscle used to its utmost. Furthermore, many body\nfunctions are traditionally monitored only rarely and separated by a considerable\nperiod of time. This can give a very incomplete picture of what is really happening.\nConsider a patient visiting a doctor for a blood pressure check; he/she may be anxious\nand thus have elevated pressure resulting in an inaccurate diagnosis. If, however, the\npatient can be fitted with a simple monitoring system that requires no intervention,\nthen a picture can be built up of how the pressure changes through the day when\nhe/she goes about their normal business. This will give a better picture of what is\nhappening and remove inaccurate results caused by going to visit the doctor. To\nachieve these requirements, monitoring of movement and body function are essential.\nThis monitoring requires the sensors and wireless system to be very lightweight and\nto be integrated unobtrusively into the clothing.\nA Body Sensor Network (BSN) allows the integration of intelligent, miniaturized,\nlow power, invasive and non-invasive sensor nodes to monitor body function and the\nA. Håkansson et al. (Eds.): KES-AMSTA 2009, LNAI 5559, pp. 335–345, 2009.\n© Springer-Verlag Berlin Heidelberg 2009\n\n\x0c336\n\nS. Ullah, X. An, and K.S. Kwak\n\nsurrounding environment. Each intelligent node has enough capability to process and\nforward information to a base station for diagnosis and prescription. A BSN provides\nlong term health monitoring of patients under natural physiological states without\nconstraining their normal activities. It can be used to develop a smart and affordable\nhealth care system and can be a part of diagnostic procedure, maintenance of chronic\ncondition, supervised recovery from a surgical procedure and to handle emergency\nevents [1].\nA number of ongoing projects such as CodeBlue, MobiHealth, and iSIM have contributed to establish a proactive and unobtrusive BSN system [2]-[4]. A system architecture presented in [5] performs real time analysis of sensor’s data, provides real\ntime feedback to the user, and forwards the user’s information to a telemedicine\nserver. UbiMon aims to develop a smart and an affordable health care system [6].\nMIT Media Lab is developing MIThril that gives a complete insight of humanmachine interface [7]. HIT lab focuses on quality interfaces and innovative wearable\ncomputers [8]. IEEE 802.15.6 aims to provide power-efficient in-body and on-body\nwireless communication standards for medical and non-medical a ...

# %%
len(vocabulary)
# Out:
# 6426

# %%
vocabulary
# Out:
# {'weissman',
#  'radiu',
#  'surpris',
#  'similarli',
#  'analogu',
#  'az',
#  'spain',
#  'lalwani',
#  '2014',
#  'news',
#  'sphere',
#  'shimamoto',
#  'fifteen',
#  'sh',
#  'kbk',
#  'chest',
#  'abil',
#  '2012',
#  'perspect',
#  'quadrat',
#  'homeomorph',
#  'etc',
#  'kaski',
#  'xu',
#  'si',
#  'outgo',
#  'bori',
#  'gegenbau',
#  'kakp',
#  'npw',
#  '1382',
#  'hang',
#  'occurr',
#  'szkola',
#  'pseudocod',
#  'randgraph',
#  'miracl',
#  'contend',
#  'eleg',
#  'soni',
#  'hz',
#  'oxygen',
#  'darkest',
#  'ric',
#  'variant',
#  'insecur',
#  'kl',
#  'lne',
#  'countless',
#  'send',
#  'azuma',
#  'someth',
#  'wattsstrogatz',
#  'cond',
#  'therapi',
#  'typewrit',
#  'kannan',
#  'spuriou',
#  'medina',
#  'coat',
#  'unlicens',
#  'mistak',
#  'preserv',
#  'choos',
#  'straightforward',
#  'kreutz',
#  'fahnenhomogen',
#  'neighborhood',
#  'keevash',
#  '3115',
#  'verif',
#  'versa',
#  'substructur',
#  'incheon',
#  'record',
#  'classroom',
#  '1960',
#  'dass',
#  'resort',
#  'wit',
#  'inflat',
#  'murray',
#  'amin',
#  'titl',
#  'byer',
#  '1234',
#  'wiesner',
#  'mislead',
#  'ambulatoryeeg',
#  'lena',
#  'tactic',
#  'biplan',
#  'pam',
#  'multitud',
#  'seri',
#  'bump',
#  'placehold',
#  'distant',
#  'lin',
#  'far',
#  'edit',
#  'obligatori',
#  'rout',
#  'essenti',
#  'eldar',
#  'ito',
#  'respons',
#  'instruct',
#  'pub',
#  'hot',
#  'shashi',
#  'dnsx',
#  'constitut',
#  'aros',
#  'document',
#  'eur',
#  'automata',
#  'tsachi',
#  'biosensor',
#  'dehornoy',
#  'revolution',
#  'arm',
#  'unimodular',
#  'mahajan',
#  'exampl',
#  'kxk0',
#  'meyer',
#  'hungarica',
#  'hundr',
#  'hope',
#  'element',
#  'jgt',
#  'street',
#  'iscuss',
#  'event',
#  'phi',
#  'quantumwork',
#  'ypr',
#  '1600',
#  'burlington',
#  'relationship',
#  '2003',
#  'ieeetran',
#  'dummi',
#  'possess',
#  'nlo',
#  'counterproduct',
#  'ldpc',
#  '2567',
#  'qo',
#  'concurr',
#  'paramet',
#  'gastpar',
#  'distinguish',
#  'qualif',
#  'northholland',
#  'temperatur',
#  'wideband',
#  'ismict',
#  'wiki',
#  'icst',
#  'ensu',
#  'ultra',
#  'moreov',
#  '5677',
#  'reason',
#  'foucard',
#  'analogon',
#  'shorter',
#  'manar',
#  'brian',
#  'lohsoonthorn',
#  'eth',
#  'digit',
#  'host',
#  'bag',
#  'rz',
#  'bsn',
#  'cei',
#  'load',
#  'borrow',
#  'intermedi',
#  'corpor',
#  'remark',
#  'reboot',
#  'platon',
#  'sel',
#  'liner',
#  'taraz',
#  'except',
#  '0911',
#  'content',
#  'defibril',
#  'neq',
#  'toeb',
#  'circl',
#  'best',
#  'khan',
#  'improp',
#  'mpdu',
#  'compound',
#  'ength',
#  'retun',
#  'ihw',
#  'phenomenon',
#  'europ',
#  'iwuc',
#  're',
#  'collect',
#  'pave',
#  'aloha',
#  'almost',
#  'afresh',
#  'berri',
#  'clearer',
#  'baghdadi',
#  'elki',
#  'recover',
#  'tropp',
#  'depend',
#  'lloyd',
#  'endors',
#  'undecid',
#  'tit',
#  'claim',
#  'student',
#  'seminar',
#  'indirectli',
#  'phrase',
#  'schu',
#  'restat',
#  'francisco',
#  'mulder',
#  'bv',
#  'seed',
#  'truli',
#  'anayak',
#  'keshavan',
#  'rolf',
#  'queue',
#  'jacobian',
#  'nter',
#  'be',
#  'teirlinck',
#  'fortnow',
#  'pendant',
#  'slim',
#  'aff',
#  'award',
#  'recent',
#  'late',
#  'xr',
#  'coher',
#  'identifi',
#  'haeflig',
#  'enhanc',
#  'necessari',
#  '115a',
#  'rembo',
#  'exclus',
#  'smv',
#  'rner',
#  'fusco',
#  'av',
#  'sg3a',
#  'interchang',
#  'maxiter',
#  'aigner',
#  'exclud',
#  'represent',
#  'ky',
#  'kohnert',
#  'score',
#  'alamito',
#  'agenc',
#  'inspir',
#  'demo',
#  'lce',
#  'tree',
#  'helleseth',
#  'vacuou',
#  'combinatori',
#  '1016',
#  'price',
#  'chih',
#  'rr',
#  'absorpt',
#  'm185',
#  '1584',
#  'wainwright',
#  '2004',
#  'telemedicin',
#  'kx0j',
#  'prior',
#  'hs',
#  'cij',
#  'reidel',
#  'bitay',
#  'virtual',
#  '1447',
#  'tomasi',
#  'tail',
#  '0804',
#  'kuk',
#  'properti',
#  'lz',
#  'lation',
#  'econometr',
#  'overrelax',
#  'indistinguishclass',
#  'anderson',
#  'ouput',
#  'studia',
#  'foundat',
#  '1974',
#  'lend',
#  'dxdi',
#  'tech',
#  'tcc',
#  'hermitean',
#  'smoother',
#  'regular',
#  'timo',
#  'hyperbol',
#  'autocorr',
#  'plusieur',
#  'spread',
#  'form',
#  'html',
#  'secret',
#  'codeword',
#  'greatest',
#  'koric',
#  'bladder',
#  '1694',
#  'org',
#  'vu',
#  'beg',
#  'ik',
#  'recal',
#  'survey',
#  'restreint',
#  'handbook',
#  '0907',
#  'subscript',
#  'quartic',
#  'subqor',
#  'explicitli',
#  'entertain',
#  '1992',
#  'cea',
#  'darpa',
#  'irrespect',
#  'kumar',
#  '2700',
#  'sight',
#  'target',
#  'elia',
#  'piec',
#  'cheme',
#  'proposit',
#  'deborah',
#  'loadclass',
#  'joe',
#  'column',
#  'border',
#  'incompar',
#  'det',
#  'stege',
#  'ht',
#  'adler',
#  'problemi',
#  'signific',
#  'demot',
#  'mcgraw',
#  'prescrib',
#  'rucinski',
#  'seven',
#  'boulder',
#  'correct',
#  'incoher',
#  'ullah',
#  'bajaj',
#  'simplex',
#  'metz',
#  'recurr',
#  '2183',
#  'bilinear',
#  'rariti',
#  '1441',
#  'ip',
#  'louxin',
#  'exit',
#  'arrang',
#  'ulrik',
#  'friperting',
#  'pure',
#  'subgradi',
#  'kvgg',
#  'norro',
#  'physica',
#  'solid',
#  'draft',
#  'ottingham',
#  'david',
#  'ree',
#  'cambridg',
#  'stein',
#  'phelp',
#  'nonuniformli',
#  'chain',
#  'beacon',
#  'athanasio',
#  'imperi',
#  'multipath',
#  'neuss',
#  'pigeonhol',
#  'perfroamnc',
#  'isbn',
#  'grid',
#  'roughli',
#  'yt',
#  'ucla',
#  'alloc',
#  'itfsr',
#  'count',
#  'journal',
#  'qk',
#  'ehrenfest',
#  'hu06',
#  'research',
#  'il',
#  'dot',
#  'electron',
#  'share',
#  '3378',
#  'colbourn',
#  'anti',
#  'cet',
#  'tfsr',
#  'leech',
#  'simpl',
#  'dmv',
#  'foucart',
#  'mahindru',
#  'situat',
#  'swiercz',
#  'newton',
#  '1978',
#  'proper',
#  '2192',
#  'respect',
#  'enr',
#  'rahmat',
#  'nr',
#  'neyman',
#  'samii',
#  'es',
#  'resolv',
#  'exec',
#  'crypto',
#  'hutter',
#  'yehuda',
#  'ambiti',
#  'slot',
#  'impli',
#  'classifi',
#  'insuffici',
#  'xjn',
#  'deadlin',
#  'twentyeighth',
#  'ubimon',
#  'irreduc',
#  '1933',
#  'xj',
#  'quantum',
#  'cultur',
#  'analyz',
#  'derick',
#  '2504',
#  'histogram',
#  'chi',
#  'commut',
#  'bootstrap',
#  'kleinberg',
#  'matthia',
#  'codeblu',
#  'kitaev',
#  'princip',
#  'notion',
#  '5758',
#  'jonathan',
#  'likewis',
#  'angl',
#  'sole',
#  'berger',
#  'singular',
#  'qot',
#  'channel',
#  'masiero',
#  'forev',
#  'moir',
#  'zadv',
#  'hospit',
#  '3329',
#  'consolid',
#  'revers',
#  'rake',
#  'cancer',
#  'extremum',
#  'neither',
#  'ja',
#  'anant',
#  'know',
#  'hardi',
#  'highest',
#  'jacobi',
#  'encrypt',
#  'y1n1',
#  'logn',
#  'rcrit',
#  'cisco',
#  'berg',
#  'iee',
#  '4169',
#  'ordnen',
#  'immedi',
#  'materi',
#  'assur',
#  'nanosecond',
#  'fall',
#  'integrand',
#  'ahpi',
#  'examin',
#  'cancel',
#  'triplet',
#  'pyx',
#  'concaten',
#  'su',
#  'cubic',
#  'reward',
#  'reichardt',
#  'kpe',
#  'reader',
#  'palmtop',
#  'andr',
#  'ray',
#  'quantumli',
#  'renner',
#  'udp',
#  'sanghavi',
#  'cifar',
#  'southern',
#  'mithril',
#  '1568',
#  'xh',
#  '1721',
#  'infarct',
#  'tbr',
#  'john',
#  'vorkommen',
#  'variabl',
#  'counterpart',
#  'money',
#  'licens',
#  'unord',
#  'oral',
#  'prefix',
#  'hpe',
#  'pkji',
#  'procedur',
#  'across',
#  'inscrib',
#  'ucsecur',
#  'zigangirov',
#  'robert',
#  'gabor',
#  'deriv',
#  'gribonvalnielsen',
#  'steinersch',
#  'euler',
#  'suzuki',
#  'baryshnikov',
#  'by13',
#  'decis',
#  'brother',
#  'bolloba',
#  'ordinari',
#  'yjn',
#  'australian',
#  'vontobel',
#  'breviti',
#  'abort',
#  'correspond',
#  'heron',
#  'manuscript',
#  'hopcroft',
#  'schwartz',
#  'erasur',
#  'supermartingal',
#  'npn',
#  'kramer',
#  'centrosymmetr',
#  'way',
#  'membership',
#  'speed',
#  'montr',
#  'disturb',
#  'accept',
#  'rocketfuel',
#  '0807',
#  'packet',
#  '8a20',
#  'itft',
#  'komplexita',
#  'hut',
#  'trafficbas',
#  'gt',
#  'etsi',
#  '5ghz',
#  'ker',
#  'notabl',
#  'agl',
#  'techn',
#  'muellerquad',
#  'zt',
#  'unnorm',
#  'prepar',
#  'routin',
#  '2231',
#  'qualitatif',
#  '18th',
#  'nineteenth',
#  'kr',
#  'placement',
#  'regroup',
#  'emg',
#  'tucker',
#  'forbid',
#  'ravindran',
#  'zero',
#  'shell',
#  'barron',
#  'scd',
#  'account',
#  'wilson',
#  'strauss',
#  'washington',
#  'fix',
#  'dku',
#  'happi',
#  'vagu',
#  '5mhz',
#  'transmit',
#  'driver',
#  'minimum',
#  'csisza',
#  'put',
#  'gribonv',
#  'thanclass',
#  'joseph',
#  'columbia',
#  'decemb',
#  'concentr',
#  'manifestli',
#  'heavi',
#  'period',
#  'liu',
#  'vi',
#  'orthonorm',
#  'constrain',
#  'xxxx',
#  'catalan',
#  'length',
#  'eirola',
#  'frame',
#  'thick',
#  'infrastructur',
#  'mirror',
#  'kzk0',
#  'lo',
#  'clariti',
#  'tw',
#  'doubli',
#  'fixedcomposit',
#  'natur',
#  'ambigu',
#  'save',
#  'unreli',
#  'radiowav',
#  'interplay',
#  'descript',
#  'fourier',
#  'evgeni',
#  'lattic',
#  'justif',
#  'visual',
#  'orlando',
#  'copyright',
#  'train',
#  'intellig',
#  'mainten',
#  'hand',
#  'life',
#  '1985',
#  'modif',
#  'corollari',
#  'syntact',
#  'nth',
#  'evolut',
#  '1106',
#  'type',
#  'madrid',
#  'pu',
#  'tighter',
#  'methodolog',
#  'oppenheim',
#  'evolutionari',
#  'tanh',
#  'endow',
#  'discov',
#  'url',
#  'ture',
#  'neglect',
#  'languag',
#  'arriv',
#  'qd',
#  '2000',
#  'antipod',
#  'futur',
#  'growth',
#  'gill',
#  'easi',
#  'theme',
#  'sun',
#  'classicaluc',
#  'signatur',
#  'resend',
#  'cryptograph',
#  'grassman',
#  '1990',
#  'iwuwbt',
#  'curi',
#  'bohman',
#  'conting',
#  'neo',
#  'tzafriri',
#  'wp',
#  'quantit',
#  'ra',
#  'would',
#  'choose',
#  'fn',
#  'good',
#  'efron',
#  'overlap',
#  'xa',
#  'dokladi',
#  'plet',
#  'cedex',
#  'meanwhil',
#  'degre',
#  'compact',
#  'ailath',
#  '1n0n',
#  'ly',
#  'pacif',
#  'besid',
#  'experiment',
#  'doubl',
#  'succes',
#  'ishai',
#  'someon',
#  'waterloo',
#  'tell',
#  'finit',
#  'sr',
#  'invers',
#  'wast',
#  'ec',
#  'sci',
#  'failur',
#  'payload',
#  'execn',
#  'jonckhe',
#  'pem1',
#  'economi',
#  'mke',
#  'reduct',
#  'sport',
#  '10th',
#  'berlin',
#  'piper',
#  'satisfi',
#  'immort',
#  '1569',
#  'indebt',
#  'sov',
#  'sparsiti',
#  'submessag',
#  'flavour',
#  'ebij',
#  'tschel',
#  'tutoriel',
#  'proj',
#  'dk',
#  'gibb',
#  'informatiqu',
#  'limt',
#  'gelfand',
#  'deal',
#  'ost',
#  'forward',
#  'tfdt',
#  'krawtchouk',
#  'opinion',
#  'sender',
#  'weaker',
#  'reinterpret',
#  'groen',
#  'overal',
#  'fehr',
#  'treatment',
#  '33rd',
#  'montanari',
#  'hardli',
#  'sc',
#  'hurt',
#  'nevertheless',
#  'presenc',
#  'nondeterminist',
#  'redund',
#  'properli',
#  'amplif',
#  'end',
#  'flag',
#  'buhrman',
#  'snow',
#  'ulasbagci',
#  'valid',
#  '1966',
#  'steel',
#  'dreien',
#  'indefinit',
#  'mani',
#  'acad',
#  'demand',
#  'rsr',
#  '2488',
#  'societi',
#  'poisson',
#  'questionnair',
#  'barroso',
#  'richer',
#  'pearson',
#  '0710',
#  'reconstruct',
#  'curvatur',
#  'wigger',
#  'discretis',
#  'pleas',
#  'taormina',
#  'kilgu',
#  'idea',
#  'theorem',
#  'intens',
#  'nearoptim',
#  '3xyz',
#  'nonblock',
#  'juni',
#  'fuch',
#  'useless',
#  'v7n3',
#  'kudryashov',
#  'servlet',
#  'major',
#  'permiss',
#  '1967',
#  'brazilian',
#  'setup',
#  'canada',
#  'probabilisticpolynomi',
#  'invit',
#  'mem',
#  'thoma',
#  'practic',
#  'user',
#  'rocki',
#  'klog',
#  'annihil',
#  'minist',
#  'huam',
#  'kz',
#  'toru',
#  'ref',
#  'gf',
#  'electr',
#  'agre',
#  'spatial',
#  'contemporari',
#  'hx',
#  'xml',
#  'elsewher',
#  'schober',
#  'zo',
#  'effort',
#  'advdummi',
#  'luc',
#  'cardin',
#  'mari',
#  'maxni',
#  'stabl',
#  'start',
#  'request',
#  'weyl',
#  'felt',
#  'herrera',
#  'photon',
#  'corlemma',
#  'instant',
#  'pni',
#  'st',
#  'propos',
#  'copi',
#  'ussr',
#  'md',
#  'call',
#  'mid',
#  'meshulam',
#  '3200',
#  'and',
#  'brust',
#  '2017',
#  'sp',
#  'computerbas',
#  'chart',
#  'bs',
#  'electrocardiogram',
#  'mbp',
#  'center',
#  'employ',
#  'part',
#  'seek',
#  'desir',
#  'mr',
#  'connect',
#  'leak',
#  'latr',
#  'empti',
#  'magnitud',
#  '45th',
#  '1438',
#  'literatur',
#  'ijcv',
#  'minima',
#  'matta',
#  'prefer',
#  'kernal',
#  'test',
#  'crucial',
#  'brouwer',
#  'lnc',
#  'dissolv',
#  'represen',
#  'astoundingli',
#  'manoj',
#  'lee2',
#  'lioumpa',
#  'parametris',
#  'crepeau',
#  'noon',
#  '5577',
#  'extend',
#  'capit',
#  'salvail',
#  'affect',
#  'line',
#  'extra',
#  'ntt',
#  'rewind',
#  'vice',
#  'maxim',
#  'cfm',
#  'uoregon',
#  'analog',
#  'caviti',
#  'stem',
#  'slowli',
#  'solver',
#  'lagrang',
#  'truncat',
#  'ml',
#  'mesh',
#  'tc',
#  'andrebarbosa',
#  'breiman',
#  'insepar',
#  'grove',
#  'cr',
#  'sin',
#  ...}

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer(analyzer = "word",vocabulary =vocabulary , tokenizer = None, preprocessor = None, stop_words = 'english', max_features = 5000) 
train_data_features = vectorizer.fit_transform(results_text)
#vectorizer.transform(["Machine learning is great"]).toarray()

# %%
print(train_data_features)
# Out:
#   (0, 8)	1
#   (0, 203)	1
#   (0, 206)	1
#   (0, 207)	1
#   (0, 208)	3
#   (0, 209)	1
#   (0, 210)	1
#   (0, 295)	1
#   (0, 302)	1
#   (0, 384)	1
#   (0, 390)	1
#   (0, 405)	1
#   (0, 411)	2
#   (0, 422)	5
#   (0, 451)	14
#   (0, 489)	2
#   (0, 546)	1
#   (0, 555)	3
#   (0, 556)	2
#   (0, 561)	1
#   (0, 616)	1
#   (0, 617)	1
#   (0, 619)	4
#   (0, 623)	1
#   (0, 637)	1
#   :	:
#   (24, 6154)	1
#   (24, 6155)	1
#   (24, 6163)	1
#   (24, 6169)	2
#   (24, 6174)	6
#   (24, 6210)	1
#   (24, 6229)	1
#   (24, 6232)	1
#   (24, 6238)	23
#   (24, 6241)	1
#   (24, 6242)	2
#   (24, 6254)	5
#   (24, 6265)	12
#   (24, 6266)	3
#   (24, 6278)	2
#   (24, 6286)	8
#   (24, 6292)	4
#   (24, 6306)	1
#   (24, 6347)	1
#   (24, 6349)	1
#   (24, 6350)	2
#   (24, 6369)	1
#   (24, 6390)	2
#   (24, 6400)	1
#   (24, 6402)	1

# %%
vectorizer.vocabulary_
# Out:
# {'0002': 0,
#  '0041': 1,
#  '0044': 2,
#  '0045': 3,
#  '0156': 4,
#  '01ma': 5,
#  '0200': 6,
#  '0636': 7,
#  '0704': 8,
#  '0709': 9,
#  '0710': 10,
#  '074e': 11,
#  '0803': 12,
#  '0804': 13,
#  '0806': 14,
#  '0807': 15,
#  '0808': 16,
#  '0811': 17,
#  '0812': 18,
#  '0862': 19,
#  '0900': 20,
#  '0901': 21,
#  '0902': 22,
#  '0903': 23,
#  '0904': 24,
#  '0907': 25,
#  '0910': 26,
#  '0911': 27,
#  '0dbm': 28,
#  '0ih0': 29,
#  '0n1n': 30,
#  '0pex': 31,
#  '1000': 32,
#  '1002': 33,
#  '1016': 34,
#  '1025': 35,
#  '1045': 36,
#  '1060': 37,
#  '1085': 38,
#  '1095': 39,
#  '1099': 40,
#  '10m': 41,
#  '10th': 42,
#  '1104': 43,
#  '1106': 44,
#  '1108': 45,
#  '1117': 46,
#  '1123': 47,
#  '114a': 48,
#  '114b': 49,
#  '114c': 50,
#  '1150': 51,
#  '115a': 52,
#  '115b': 53,
#  '11u1': 54,
#  '1201': 55,
#  '1212': 56,
#  '1223': 57,
#  '1229': 58,
#  '1234': 59,
#  '1236': 60,
#  '1238': 61,
#  '1245': 62,
#  '1248': 63,
#  '1261': 64,
#  '1265': 65,
#  '1267': 66,
#  '1268': 67,
#  '1269': 68,
#  '1273': 69,
#  '1275': 70,
#  '1288': 71,
#  '1289': 72,
#  '12s0': 73,
#  '1302': 74,
#  '1306': 75,
#  '1341': 76,
#  '1343': 77,
#  '1344': 78,
#  '1359': 79,
#  '1365': 80,
#  '1382': 81,
#  '1391': 82,
#  '1393': 83,
#  '1397': 84,
#  '1400': 85,
#  '1416': 86,
#  '1419': 87,
#  '1420': 88,
#  '1423': 89,
#  '1426': 90,
#  '1434': 91,
#  '1435': 92,
#  '1436': 93,
#  '1438': 94,
#  '1441': 95,
#  '1447': 96,
#  '1450': 97,
#  '1462': 98,
#  '1472': 99,
#  '1484': 100,
#  '1493': 101,
#  '14th': 102,
#  '1501': 103,
#  '1505': 104,
#  '1510': 105,
#  '1523': 106,
#  '1527': 107,
#  '1556': 108,
#  '1567': 109,
#  '1568': 110,
#  '1569': 111,
#  '1570': 112,
#  '1584': 113,
#  '1587': 114,
#  '1600': 115,
#  '1605': 116,
#  '1632': 117,
#  '1641': 118,
#  '1650': 119,
#  '1664': 120,
#  '1675': 121,
#  '1682': 122,
#  '1694': 123,
#  '16th': 124,
#  '1721': 125,
#  '1737': 126,
#  '1744': 127,
#  '1754': 128,
#  '1761': 129,
#  '1764': 130,
#  '1766': 131,
#  '1770': 132,
#  '1800': 133,
#  '1801': 134,
#  '1804': 135,
#  '1839': 136,
#  '1853': 137,
#  '1860': 138,
#  '1861': 139,
#  '1863': 140,
#  '1865': 141,
#  '1873': 142,
#  '1874': 143,
#  '1886': 144,
#  '18th': 145,
#  '1900': 146,
#  '1933': 147,
#  '1935': 148,
#  '1937': 149,
#  '1938': 150,
#  '1940': 151,
#  '1948': 152,
#  '1949': 153,
#  '1950': 154,
#  '1952': 155,
#  '1953': 156,
#  '1954': 157,
#  '1956': 158,
#  '1959': 159,
#  '1960': 160,
#  '1961': 161,
#  '1962': 162,
#  '1963': 163,
#  '1964': 164,
#  '1965': 165,
#  '1966': 166,
#  '1967': 167,
#  '1968': 168,
#  '1969': 169,
#  '1970': 170,
#  '1971': 171,
#  '1972': 172,
#  '1973': 173,
#  '1974': 174,
#  '1975': 175,
#  '1976': 176,
#  '1977': 177,
#  '1978': 178,
#  '1979': 179,
#  '1980': 180,
#  '1981': 181,
#  '1982': 182,
#  '1983': 183,
#  '1984': 184,
#  '1985': 185,
#  '1986': 186,
#  '1987': 187,
#  '1988': 188,
#  '1989': 189,
#  '1990': 190,
#  '1991': 191,
#  '1992': 192,
#  '1993': 193,
#  '1994': 194,
#  '1995': 195,
#  '1996': 196,
#  '1997': 197,
#  '1998': 198,
#  '1999': 199,
#  '1ih1': 200,
#  '1n0': 201,
#  '1n0n': 202,
#  '2000': 203,
#  '2001': 204,
#  '2002': 205,
#  '2003': 206,
#  '2004': 207,
#  '2005': 208,
#  '2006': 209,
#  '2007': 210,
#  '2008': 211,
#  '2009': 212,
#  '2010': 213,
#  '2011': 214,
#  '2012': 215,
#  '2013': 216,
#  '2014': 217,
#  '2015': 218,
#  '2017': 219,
#  '2018': 220,
#  '2020': 221,
#  '20th': 222,
#  '2139': 223,
#  '2145': 224,
#  '215t': 225,
#  '2177': 226,
#  '2182': 227,
#  '2183': 228,
#  '2192': 229,
#  '2197': 230,
#  '2200': 231,
#  '2202': 232,
#  '2231': 233,
#  '2235': 234,
#  '22nd': 235,
#  '22u2': 236,
#  '2398': 237,
#  '23rd': 238,
#  '240d': 239,
#  '2437': 240,
#  '2440': 241,
#  '2477': 242,
#  '2488': 243,
#  '2502': 244,
#  '2504': 245,
#  '2521': 246,
#  '2523': 247,
#  '2533': 248,
#  '2541': 249,
#  '2557': 250,
#  '2558': 251,
#  '2561': 252,
#  '2563': 253,
#  '2567': 254,
#  '2595': 255,
#  '25m': 256,
#  '26th': 257,
#  '2700': 258,
#  '2702': 259,
#  '2714': 260,
#  '27db': 261,
#  '27th': 262,
#  '2845': 263,
#  '2862': 264,
#  '2893': 265,
#  '2933': 266,
#  '2952': 267,
#  '2a20': 268,
#  '2e2m': 269,
#  '2e33': 270,
#  '2min': 271,
#  '2pn': 272,
#  '2the': 273,
#  '3000': 274,
#  '3010': 275,
#  '3022': 276,
#  '3060': 277,
#  '3063': 278,
#  '3074': 279,
#  '3079': 280,
#  '3080': 281,
#  '30th': 282,
#  '3115': 283,
#  '3119': 284,
#  '3151': 285,
#  '3159': 286,
#  '3200': 287,
#  '3270': 288,
#  '3275': 289,
#  '3286': 290,
#  '3320': 291,
#  '3325': 292,
#  '3329': 293,
#  '3333': 294,
#  '3378': 295,
#  '33rd': 296,
#  '3414': 297,
#  '3417': 298,
#  '3628': 299,
#  '3754': 300,
#  '3778': 301,
#  '3788': 302,
#  '3829': 303,
#  '3965': 304,
#  '3987': 305,
#  '39th': 306,
#  '3sec': 307,
#  '3xyz': 308,
#  '4000': 309,
#  '4096': 310,
#  '40th': 311,
#  '4169': 312,
#  '41st': 313,
#  '4203': 314,
#  '4215': 315,
#  '4265': 316,
#  '4273': 317,
#  '4392': 318,
#  '43rd': 319,
#  '4439': 320,
#  '4447': 321,
#  '4462': 322,
#  '4478': 323,
#  '4496': 324,
#  '4581': 325,
#  '45th': 326,
#  '4634': 327,
#  '4643': 328,
#  '4692': 329,
#  '4702': 330,
#  '48th': 331,
#  '4953': 332,
#  '4978': 333,
#  '4a20': 334,
#  '5004': 335,
#  '5157': 336,
#  '5212': 337,
#  '5251': 338,
#  '5390': 339,
#  '5406': 340,
#  '5424': 341,
#  '5425': 342,
#  '5431': 343,
#  '5444': 344,
#  '5559': 345,
#  '5577': 346,
#  '5677': 347,
#  '5758': 348,
#  '5772': 349,
#  '5963': 350,
#  '5dbm': 351,
#  '5ghz': 352,
#  '5mhz': 353,
#  '6279': 354,
#  '6648': 355,
#  '6745': 356,
#  '6759': 357,
#  '7000': 358,
#  '7027': 359,
#  '7055': 360,
#  '7299': 361,
#  '82sm': 362,
#  '8580': 363,
#  '8a20': 364,
#  'aa': 365,
#  'aa05': 366,
#  'aachen': 367,
#  'aalto': 368,
#  'aaronson': 369,
#  'aat': 370,
#  'ab': 371,
#  'abc': 372,
#  'abdeg': 373,
#  'abelian': 374,
#  'abep': 375,
#  'aber': 376,
#  'abh': 377,
#  'abil': 378,
#  'abk': 379,
#  'abl': 380,
#  'abn': 381,
#  'abnorm': 382,
#  'abort': 383,
#  'abovement': 384,
#  'absenc': 385,
#  'absent': 386,
#  'absolut': 387,
#  'absorb': 388,
#  'absorpt': 389,
#  'abstract': 390,
#  'abund': 391,
#  'abus': 392,
#  'abut': 393,
#  'ac': 394,
#  'acad': 395,
#  'academ': 396,
#  'acc': 397,
#  'acceleromet': 398,
#  'accept': 399,
#  'access': 400,
#  'accommod': 401,
#  'accomplish': 402,
#  'accord': 403,
#  'accordingli': 404,
#  'account': 405,
#  'accumul': 406,
#  'accur': 407,
#  'accuraci': 408,
#  'achiev': 409,
#  'achievabl': 410,
#  'acknowledg': 411,
#  'ackowledg': 412,
#  'acm': 413,
#  'acoust': 414,
#  'acquaint': 415,
#  'acquir': 416,
#  'across': 417,
#  'act': 418,
#  'acta': 419,
#  'action': 420,
#  'activ': 421,
#  'actual': 422,
#  'actuat': 423,
#  'ad': 424,
#  'adapt': 425,
#  'add': 426,
#  'addison': 427,
#  'addisonwesley': 428,
#  'addit': 429,
#  'address': 430,
#  'adequ': 431,
#  'adhoc': 432,
#  'adipos': 433,
#  'adjac': 434,
#  'adjoin': 435,
#  'adjust': 436,
#  'adler': 437,
#  'admit': 438,
#  'adolesc': 439,
#  'adopt': 440,
#  'adrian': 441,
#  'adriano': 442,
#  'adv': 443,
#  'advanc': 444,
#  'advantag': 445,
#  'advclass': 446,
#  'advdummi': 447,
#  'adversari': 448,
#  'advic': 449,
#  'aegean': 450,
#  'aep': 451,
#  'aesthet': 452,
#  'aff': 453,
#  'affair': 454,
#  'affect': 455,
#  'affili': 456,
#  'affin': 457,
#  'affirm': 458,
#  'afford': 459,
#  'aforement': 460,
#  'afosr': 461,
#  'afresh': 462,
#  'afterward': 463,
#  'ag': 464,
#  'age': 465,
#  'agenc': 466,
#  'agent': 467,
#  'aggreg': 468,
#  'agl': 469,
#  'ago': 470,
#  'agre': 471,
#  'aharonov': 472,
#  'ahasanun': 473,
#  'ahlswed': 474,
#  'ahpi': 475,
#  'ai': 476,
#  'aict': 477,
#  'aigner': 478,
#  'aihv': 479,
#  'aij': 480,
#  'aik': 481,
#  'ailath': 482,
#  'aim': 483,
#  'air': 484,
#  'aivfg': 485,
#  'aj': 486,
#  'ak': 487,
#  'akj': 488,
#  'al': 489,
#  'alamito': 490,
#  'alan': 491,
#  'alarm': 492,
#  'albanes': 493,
#  'albeit': 494,
#  'albenes': 495,
#  'albert': 496,
#  'ale': 497,
#  'alert': 498,
#  'alessandro': 499,
#  'alexandria': 500,
#  'alexandrov': 501,
#  'algebr': 502,
#  'algebra': 503,
#  'algoqp': 504,
#  'algorithm': 505,
#  'algorithmica': 506,
#  'alic': 507,
#  'align': 508,
#  'allen': 509,
#  'allencahn': 510,
#  'allerton': 511,
#  'allgemein': 512,
#  'alloc': 513,
#  'allow': 514,
#  'almost': 515,
#  'aloha': 516,
#  'alon': 517,
#  'along': 518,
#  'alphabet': 519,
#  'alreadi': 520,
#  'also': 521,
#  'alter': 522,
#  'altern': 523,
#  'althau': 524,
#  'although': 525,
#  'altruist': 526,
#  'alumina': 527,
#  'alway': 528,
#  'amaz': 529,
#  'ambaini': 530,
#  'ambigu': 531,
#  'ambiti': 532,
#  'ambulatori': 533,
#  'ambulatoryeeg': 534,
#  'amc': 535,
#  'amen': 536,
#  'amenta': 537,
#  'amer': 538,
#  'american': 539,
#  'amin': 540,
#  'amit': 541,
#  'amo': 542,
#  'among': 543,
#  'amongst': 544,
#  'amount': 545,
#  'amplif': 546,
#  'amplifi': 547,
#  'amplitud': 548,
#  'amraoui': 549,
#  'amsta': 550,
#  'amsterdam': 551,
#  'an': 552,
#  'anal': 553,
#  'analiz': 554,
#  'analog': 555,
#  'analogon': 556,
#  'analogu': 557,
#  'analys': 558,
#  'analysi': 559,
#  'analyt': 560,
#  'analyz': 561,
#  'anant': 562,
#  'anayak': 563,
#  'and': 564,
#  'anderasur': 565,
#  'anderson': 566,
#  'andr': 567,
#  'andrea': 568,
#  'andrebarbosa': 569,
#  'andrew': 570,
#  'andri': 571,
#  'angel': 572,
#  'angew': 573,
#  'angl': 574,
#  'anim': 575,
#  'anisotrop': 576,
#  'anita': 577,
#  'ankl': 578,
#  'ann': 579,
#  'annal': 580,
#  'annihil': 581,
#  'annot': 582,
#  'announc': 583,
#  'annual': 584,
#  'annulu': 585,
#  'anomali': 586,
#  'anonym': 587,
#  'anoth': 588,
#  'anr': 589,
#  'answer': 590,
#  'antenna': 591,
#  'anthultra': 592,
#  'anti': 593,
#  'anticip': 594,
#  'anticod': 595,
#  'antiphas': 596,
#  'antipod': 597,
#  'antonio': 598,
#  'anxiou': 599,
#  'anxizhi': 600,
#  'anyon': 601,
#  'anyth': 602,
#  'anytim': 603,
#  'anyway': 604,
#  'anywher': 605,
#  'ap27': 606,
#  'apac': 607,
#  'apach': 608,
#  'apart': 609,
#  'appar': 610,
#  'appeal': 611,
#  'appear': 612,
#  'appendic': 613,
#  'appendix': 614,
#  'appl': 615,
#  'appli': 616,
#  'applic': 617,
#  'appreci': 618,
#  'approach': 619,
#  'appropri': 620,
#  'approx': 621,
#  'approxim': 622,
#  'apr': 623,
#  'april': 624,
#  'apt': 625,
#  'arak': 626,
#  'arbitrari': 627,
#  'arbitrarili': 628,
#  'arc': 629,
#  'arch': 630,
#  'architectur': 631,
#  'architektur': 632,
#  'archiv': 633,
#  'area': 634,
#  'arg': 635,
#  'argmin': 636,
#  'argu': 637,
#  'arguabl': 638,
#  'argument': 639,
#  'ari': 640,
#  'ariaei': 641,
#  'arif': 642,
#  'aris': 643,
#  'arithmet': 644,
#  'arizona': 645,
#  'arm': 646,
#  'aro': 647,
#  'aros': 648,
#  'around': 649,
#  'arq': 650,
#  'arrang': 651,
#  'array': 652,
#  'arrhythmia': 653,
#  'arrhythmogen': 654,
#  'arriv': 655,
#  'arrow': 656,
#  'art': 657,
#  'articl': 658,
#  'artifici': 659,
#  'arxiv': 660,
#  'aschbach': 661,
#  'ashwin': 662,
#  'asia': 663,
#  'asiacrypt': 664,
#  'asid': 665,
#  'asilomar': 666,
#  'ask': 667,
#  'aspect': 668,
#  'asr': 669,
#  'assert': 670,
#  'assess': 671,
#  'assign': 672,
#  'assist': 673,
#  'assmu': 674,
#  'assmusmattson': 675,
#  'assoc': 676,
#  'associ': 677,
#  'assort': 678,
#  'assum': 679,
#  'assumpt': 680,
#  'assur': 681,
#  'astesiano': 682,
#  'astonish': 683,
#  'astoundingli': 684,
#  'astronaut': 685,
#  'astronomi': 686,
#  'asymmetr': 687,
#  'asymptot': 688,
#  'asynchron': 689,
#  'atallah': 690,
#  'athanasio': 691,
#  'athlet': 692,
#  'ati': 693,
#  'atji': 694,
#  'atom': 695,
#  'att': 696,
#  'attach': 697,
#  'attack': 698,
#  'attain': 699,
#  'attempt': 700,
#  'attend': 701,
#  'attent': 702,
#  'attenu': 703,
#  'attract': 704,
#  'attribut': 705,
#  'audio': 706,
#  'aufgab': 707,
#  'aug': 708,
#  'augment': 709,
#  'august': 710,
#  'aujol': 711,
#  'auk': 712,
#  'australian': 713,
#  'aut': 714,
#  'authent': 715,
#  'author': 716,
#  'autocorr': 717,
#  'autocorrel': 718,
#  'autom': 719,
#  'automat': 720,
#  'automata': 721,
#  'automorph': 722,
#  'autonom': 723,
#  'aux': 724,
#  'auxiliari': 725,
#  'av': 726,
#  'avail': 727,
#  'ave': 728,
#  'averag': 729,
#  'avgustinovich': 730,
#  'avoid': 731,
#  'awar': 732,
#  'award': 733,
#  'away': 734,
#  'awgn': 735,
#  'awgnc': 736,
#  'ax': 737,
#  'axillari': 738,
#  'aydinian': 739,
#  'az': 740,
#  'aziz': 741,
#  'azuma': 742,
#  'bach': 743,
#  'bachoc': 744,
#  'back': 745,
#  'background': 746,
#  'backward': 747,
#  'bad': 748,
#  'bag': 749,
#  'bagci': 750,
#  'baghdadi': 751,
#  'bajaj': 752,
#  'bajwa': 753,
#  'baker': 754,
#  'balaji': 755,
#  'balakrishna': 756,
#  'balanc': 757,
#  'baldok': 758,
#  'ball': 759,
#  'baltimor': 760,
#  'ban': 761,
#  'banach': 762,
#  'band': 763,
#  'bandlimit': 764,
#  'bandwidth': 765,
#  'banff': 766,
#  'bang': 767,
#  'banip': 768,
#  'bannai': 769,
#  'bar': 770,
#  'barbosa': 771,
#  'bare': 772,
#  'barel': 773,
#  'baril': 774,
#  'barnum': 775,
#  'barrier': 776,
#  'barron': 777,
#  'barroso': 778,
#  'baryshnikov': 779,
#  'base': 780,
#  'basel': 781,
#  'baselin': 782,
#  'basi': 783,
#  'basic': 784,
#  'bassalygo': 785,
#  'batteri': 786,
#  'bay': 787,
#  'bayati': 788,
#  'bb': 789,
#  'bb84': 790,
#  'bc': 791,
#  'be': 792,
#  'be2i': 793,
#  'bea': 794,
#  'beacon': 795,
#  'beat': 796,
#  'beauti': 797,
#  'becam': 798,
#  'becausepof': 799,
#  'becom': 800,
#  'beg': 801,
#  'begin': 802,
#  'behav': 803,
#  'behavior': 804,
#  'behaviour': 805,
#  'behind': 806,
#  'belief': 807,
#  'believ': 808,
#  'bell': 809,
#  'belong': 810,
#  'ben': 811,
#  'benc': 812,
#  'bender': 813,
#  'bene': 814,
#  'benefit': 815,
#  'benjamin': 816,
#  'bennett': 817,
#  'benson': 818,
#  'ber': 819,
#  'berg': 820,
#  'berger': 821,
#  'berkeley': 822,
#  'berlekamp': 823,
#  'berlin': 824,
#  'bernard': 825,
#  'bernoulli': 826,
#  'bernstein': 827,
#  'berri': 828,
#  'besid': 829,
#  'best': 830,
#  'bet': 831,
#  'beth': 832,
#  'betten': 833,
#  'better': 834,
#  'between': 835,
#  'betweenn': 836,
#  'beutelspach': 837,
#  'beyond': 838,
#  'bezdek': 839,
#  'bh': 840,
#  'bi': 841,
#  'bia': 842,
#  'bias': 843,
#  'bidirect': 844,
#  'bienaym': 845,
#  'bifurc': 846,
#  'big': 847,
#  'biggest': 848,
#  'bij': 849,
#  'biject': 850,
#  'bilinear': 851,
#  'biliti': 852,
#  'billiard': 853,
#  'bin': 854,
#  'binari': 855,
#  'bind': 856,
#  'bio': 857,
#  'biocompat': 858,
#  'bioinformat': 859,
#  'biolog': 860,
#  'biomed': 861,
#  'biomem': 862,
#  'biosensor': 863,
#  'biosign': 864,
#  'biotelemetri': 865,
#  'bipartit': 866,
#  'biplan': 867,
#  'biprandgraph': 868,
#  'birgit': 869,
#  'birkha': 870,
#  'birkhaus': 871,
#  'birkhoff': 872,
#  'birth': 873,
#  'bisectionand': 874,
#  'bitay': 875,
#  'bite': 876,
#  'bitstr': 877,
#  'bittorr': 878,
#  'biu': 879,
#  'bizarr': 880,
#  'bj': 881,
#  'bjelakov': 882,
#  'bk': 883,
#  'bkf': 884,
#  'black': 885,
#  'bladder': 886,
#  'blake': 887,
#  'blanc': 888,
#  'blanchet': 889,
#  'blind': 890,
#  'blitzstein': 891,
#  'block': 892,
#  'blocklength': 893,
#  'blog': 894,
#  'blomer': 895,
#  'blondel': 896,
#  'blondia': 897,
#  'blood': 898,
#  'bloom': 899,
#  'blow': 900,
#  'blowey': 901,
#  'blue': 902,
#  'blur': 903,
#  'bn': 904,
#  'bnc': 905,
#  'board': 906,
#  'bob': 907,
#  'boca': 908,
#  'bock': 909,
#  'bodi': 910,
#  'boguna': 911,
#  'bohl': 912,
#  'bohman': 913,
#  'bold': 914,
#  'bolloba': 915,
#  'bonahon': 916,
#  'bonet': 917,
#  'bonk': 918,
#  'bonnecaz': 919,
#  'book': 920,
#  'boolean': 921,
#  'boost': 922,
#  'bootstrap': 923,
#  'borad': 924,
#  'bordeaux': 925,
#  'border': 926,
#  'bordewich': 927,
#  'borger': 928,
#  'bori': 929,
#  'borrow': 930,
#  'bose': 931,
#  'boston': 932,
#  'bother': 933,
#  'bottl': 934,
#  'bottleneck': 935,
#  'bottom': 936,
#  'boulder': 937,
#  'boundari': 938,
#  'boundedquantum': 939,
#  'bourgain': 940,
#  'bowel': 941,
#  'box': 942,
#  'boyarinov': 943,
#  'boyd': 944,
#  'bp': 945,
#  'bpp': 946,
#  'bqp': 947,
#  'br': 948,
#  'bracket': 949,
#  'bradlet': 950,
#  'braem': 951,
#  'bramoul': 952,
#  'branch': 953,
#  'brassard': 954,
#  'braun': 955,
#  'brave': 956,
#  'brazil': 957,
#  'brazilian': 958,
#  'breadth': 959,
#  'break': 960,
#  'breakthrough': 961,
#  'breiman': 962,
#  'brest': 963,
#  'breviti': 964,
#  'brian': 965,
#  'bridg': 966,
#  'bridson': 967,
#  'brief': 968,
#  'briefli': 969,
#  'bright': 970,
#  'brighton': 971,
#  'bring': 972,
#  'british': 973,
#  'britz': 974,
#  'broad': 975,
#  'broadband': 976,
#  'broadcast': 977,
#  'broader': 978,
#  'bronx': 979,
#  'bross': 980,
#  'brother': 981,
#  'brouwer': 982,
#  'brown': 983,
#  'browser': 984,
#  'bruck': 985,
#  'bruckstein': 986,
#  'brust': 987,
#  'brute': 988,
#  'bruteforc': 989,
#  'bs': 990,
#  'bsc': 991,
#  'bsn': 992,
#  'bstract': 993,
#  'bt': 994,
#  'bti': 995,
#  'bu': 996,
#  'budget': 997,
#  'buekenhout': 998,
#  'buffalo': 999,
#  ...}

# %%
train_data_features[vectorizer.vocabulary_['0704'],2]
# Out:
# 1

# %%
print(vectorizer.get_feature_names())
# Out:
# ['0704', '2000', '2003', '2004', '2005', '2006', '2007', '3378', '3788', 'abovement', 'abstract', 'account', 'acknowledg', 'actual', 'aep', 'al', 'along', 'also', 'although', 'amplif', 'analog', 'analogon', 'analyz', 'appli', 'applic', 'approach', 'apr', 'argu', 'arxiv', 'asiacrypt', 'assum', 'attain', 'avail', 'averag', 'base', 'basic', 'behav', 'believ', 'berri', 'bind', 'bjelakov', 'bori', 'breiman', 'call', 'cambridg', 'captur', 'case', 'central', 'ch', 'chapter', 'chuang', 'class', 'classic', 'clearli', 'close', 'com', 'commut', 'compact', 'comparison', 'complet', 'compress', 'comput', 'concentr', 'conclud', 'condit', 'connect', 'consequ', 'consid', 'constant', 'context', 'contrari', 'convent', 'converg', 'correspond', 'countabl', 'cover', 'cryptograph', 'data', 'defin', 'definit', 'denot', 'densiti', 'depend', 'dept', 'detail', 'diagon', 'differ', 'digit', 'dimens', 'direct', 'directli', 'discuss', 'diss', 'distanc', 'distribut', 'earli', 'eas', 'edit', 'efer', 'ei', 'eigenvalu', 'eigenvector', 'eindhoven', 'either', 'eleg', 'element', 'en', 'encod', 'end', 'entropi', 'equal', 'equival', 'ergod', 'esult', 'et', 'eth', 'ethz', 'evgeni', 'exist', 'explicitli', 'extend', 'extens', 'extract', 'fact', 'final', 'find', 'finit', 'first', 'focu', 'follow', 'form', 'full', 'function', 'furthermor', 'futur', 'gener', 'get', 'give', 'grate', 'hand', 'handl', 'henc', 'hermitian', 'hilbert', 'hold', 'howev', 'http', 'ihvi', 'ii', 'iii', 'impli', 'import', 'improv', 'independ', 'indirectli', 'inequ', 'inf', 'infimum', 'infinit', 'inform', 'instanc', 'intersci', 'introduc', 'introduct', 'invari', 'investig', 'isit', 'iv', 'jill', 'key', 'kind', 'know', 'ko', 'koric', 'larg', 'largest', 'latter', 'lead', 'least', 'leav', 'lemma', 'length', 'let', 'lim', 'line', 'lnc', 'local', 'log', 'lose', 'lower', 'main', 'mainli', 'mani', 'mathemat', 'matric', 'matrix', 'max', 'maximum', 'maxz', 'maxzn', 'may', 'mcmillan', 'mean', 'measur', 'memoryless', 'mention', 'min', 'minimum', 'monoton', 'much', 'name', 'natur', 'necessarili', 'need', 'netherland', 'neumann', 'next', 'nielsen', 'nig', 'nl', 'non', 'nonnorm', 'normal', 'note', 'notion', 'notionpof', 'ntroduct', 'number', 'nyi', 'observ', 'omit', 'one', 'onto', 'order', 'origin', 'otherwis', 'otion', 'pand', 'paper', 'part', 'particular', 'permut', 'ph', 'phd', 'philip', 'pim', 'pn', 'point', 'posit', 'possibl', 'pp', 'precis', 'preliminari', 'present', 'press', 'previou', 'principl', 'privaci', 'probabl', 'proceed', 'process', 'projector', 'proof', 'properti', 'prove', 'ps', 'pt', 'pub', 'public', 'pure', 'pz', 'qi', 'quant', 'quantum', 'random', 'rank', 'rate', 'rather', 'real', 'recal', 'recent', 'reconcili', 'reduc', 'refer', 'relev', 'reliminari', 'renner', 'research', 'resp', 'respect', 'restrict', 'result', 'rich', 'right', 'ring', 'satisfi', 'schoenmak', 'scienc', 'second', 'section', 'secur', 'see', 'septemb', 'sequenc', 'set', 'shannon', 'shorthand', 'show', 'side', 'signal', 'similarli', 'simpl', 'sinc', 'size', 'small', 'smallest', 'smooth', 'sourc', 'space', 'span', 'special', 'stage', 'standard', 'start', 'state', 'stationari', 'statist', 'student', 'studi', 'subspac', 'suffic', 'suffici', 'suitabl', 'sup', 'suppos', 'supq', 'symmetr', 'symmetri', 'system', 'szkola', 'tcc', 'technic', 'term', 'th', 'theorem', 'theori', 'therebi', 'therefor', 'thesi', 'thoma', 'throughout', 'thu', 'tight', 'tjoelker', 'tr', 'trace', 'treat', 'tue', 'tupl', 'turn', 'tuyl', 'two', 'typic', 'uncondit', 'uniform', 'univers', 'upper', 'use', 'valu', 'vanish', 'vari', 'variabl', 'variat', 'verbitskiy', 'version', 'vi', 'volum', 'von', 'well', 'weyl', 'wherea', 'wiley', 'win', 'without', 'wolf', 'work', 'write', 'yield', 'zn', 'zu']
